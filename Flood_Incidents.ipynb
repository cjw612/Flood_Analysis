# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
df = pd.read_csv('./df.csv')

# %%
flood_with_county
# Out:
#                                    station_id                timestamp  \
# 0        d83ac636-3d28-43fe-96a9-5c33dde8aebe    2022-07-21 00:08:57.2
# 1        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:18:57.382
# 2        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:28:58.358
# 3        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:38:58.793
# 4        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:48:59.713
# ...                                       ...                      ...
# 7033453  5abec613-f581-4bf9-b41c-dc0619c950c4      2020-12-11 11:30:00
# 7033454  5abec613-f581-4bf9-b41c-dc0619c950c4  2020-12-11 15:03:18.016
# 7033455  a2015019-1ecc-48a2-938d-393a289e7a9a  2020-12-11 10:05:17.262
# 7033456  ae9eb0c9-a435-4b9a-b5e2-08d00c43b231      2020-12-11 07:30:00
# 7033457  ae9eb0c9-a435-4b9a-b5e2-08d00c43b231      2020-12-11 08:50:00
#
#             value  Longitude   Latitude SIUnit                      geometry  \
# 0        0.001000  120.69100  23.903200       cm     POINT (120.691 23.9032)
# 1        0.001000  120.69100  23.903200       cm     POINT (120.691 23.9032)
# 2        0.001000  120.69100  23.903200       cm     POINT (120.691 23.9032)
# 3        0.001000  120.69100  23.903200       cm     POINT (120.691 23.9032)
# 4        0.001000  120.69100  23.903200       cm     POINT (120.691 23.9032)
# ...           ...        ...        ...      ...                         ...
# 7033453  1.545227  120.30970  23.654995       cm     POINT (120.3097 23.655)
# 7033454  1.504207  120.30970  23.654995       cm     POINT (120.3097 23.655)
# 7033455  1.022019  120.35272  23.652205       cm   POINT (120.35272 23.6522)
# 7033456  1.500928  120.47167  23.642970       cm  POINT (120.47167 23.64297)
# 7033457  1.516509  120.47167  23.642970       cm  POINT (120.47167 23.64297)
#
#          index_right COUNTYNAME TOWNNAME     VILLCODE VILLNAME  \
# 0                  3        南投縣      南投市  10008010010      軍功里
# 1                  3        南投縣      南投市  10008010010      軍功里
# 2                  3        南投縣      南投市  10008010010      軍功里
# 3                  3        南投縣      南投市  10008010010      軍功里
# 4                  3        南投縣      南投市  10008010010      軍功里
# ...              ...        ...      ...          ...      ...
# 7033453          311        雲林縣      元長鄉  10009170001      長南村
# 7033454          311        雲林縣      元長鄉  10009170001      長南村
# 7033455          316        雲林縣      土庫鎮  10009050001      忠正里
# 7033456          320        雲林縣      斗南鎮  10009020007      林子里
# 7033457          320        雲林縣      斗南鎮  10009020007      林子里
#
#                  VILLENG COUNTYID COUNTYCODE TOWNID  TOWNCODE  NOTE       Name
# 0           Jungong Vil.        M      10008    M01  10008010  None  南投縣南投市軍功里
# 1           Jungong Vil.        M      10008    M01  10008010  None  南投縣南投市軍功里
# 2           Jungong Vil.        M      10008    M01  10008010  None  南投縣南投市軍功里
# 3           Jungong Vil.        M      10008    M01  10008010  None  南投縣南投市軍功里
# 4           Jungong Vil.        M      10008    M01  10008010  None  南投縣南投市軍功里
# ...                  ...      ...        ...    ...       ...   ...        ...
# 7033453    Changnan Vil.        P      10009    P17  10009170  None  雲林縣元長鄉長南村
# 7033454    Changnan Vil.        P      10009    P17  10009170  None  雲林縣元長鄉長南村
# 7033455  Zhongzheng Vil.        P      10009    P05  10009050  None  雲林縣土庫鎮忠正里
# 7033456       Linzi Vil.        P      10009    P02  10009020  None  雲林縣斗南鎮林子里
# 7033457       Linzi Vil.        P      10009    P02  10009020  None  雲林縣斗南鎮林子里
#
# [7033402 rows x 19 columns]

# %%
# Spatial join district metadata with original df

# Load the county shapefile
counties = gpd.read_file("./Data/coordinates/VILLAGE_NLSC_1130807.shp") 

# Set CRS file according to documentation
counties = counties.to_crs(3824)

# Aggregate the POLYGON object to the town level before using it further
towns = counties.dissolve(by=["COUNTYNAME", "TOWNNAME"], as_index=False)

# Convert flood data into a GeoDataFrame
df['geometry'] = gpd.points_from_xy(df['Longitude'], df['Latitude']) 
flood_gdf = gpd.GeoDataFrame(df, geometry='geometry', crs=3824)

# Perform spatial join to get county names
flood_with_location = gpd.sjoin(flood_gdf, towns, how="inner", predicate="within")

# Extract district name and append back to original df
df['county'] = flood_with_location['COUNTYNAME']
df['town'] = flood_with_location['TOWNNAME']
df['vil'] = flood_with_location['VILLNAME']
df['district'] = df['county'].astype(str).str.cat(df['town'].astype(str))

# Ensure 'district' column in towns
towns['district'] = towns['COUNTYNAME'].astype(str).str.cat(towns['TOWNNAME'].astype(str))

# Merge town-level geometries into df
df = df.drop(columns=['geometry'])
df = df.merge(towns[['district', 'geometry']], on='district', how='inner')

# %%
df
# Out:
#                                    station_id                timestamp  \
# 0        d83ac636-3d28-43fe-96a9-5c33dde8aebe    2022-07-21 00:08:57.2
# 1        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:18:57.382
# 2        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:28:58.358
# 3        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:38:58.793
# 4        d83ac636-3d28-43fe-96a9-5c33dde8aebe  2022-07-21 00:48:59.713
# ...                                       ...                      ...
# 7033397  5abec613-f581-4bf9-b41c-dc0619c950c4      2020-12-11 11:30:00
# 7033398  5abec613-f581-4bf9-b41c-dc0619c950c4  2020-12-11 15:03:18.016
# 7033399  a2015019-1ecc-48a2-938d-393a289e7a9a  2020-12-11 10:05:17.262
# 7033400  ae9eb0c9-a435-4b9a-b5e2-08d00c43b231      2020-12-11 07:30:00
# 7033401  ae9eb0c9-a435-4b9a-b5e2-08d00c43b231      2020-12-11 08:50:00
#
#             value  Longitude   Latitude SIUnit   county town  vil district  \
# 0        0.001000  120.69100  23.903200       cm    南投縣  南投市  軍功里   南投縣南投市
# 1        0.001000  120.69100  23.903200       cm    南投縣  南投市  軍功里   南投縣南投市
# 2        0.001000  120.69100  23.903200       cm    南投縣  南投市  軍功里   南投縣南投市
# 3        0.001000  120.69100  23.903200       cm    南投縣  南投市  軍功里   南投縣南投市
# 4        0.001000  120.69100  23.903200       cm    南投縣  南投市  軍功里   南投縣南投市
# ...           ...        ...        ...      ...    ...  ...  ...      ...
# 7033397  1.545227  120.30970  23.654995       cm    雲林縣  元長鄉  長南村   雲林縣元長鄉
# 7033398  1.504207  120.30970  23.654995       cm    雲林縣  元長鄉  長南村   雲林縣元長鄉
# 7033399  1.022019  120.35272  23.652205       cm    雲林縣  土庫鎮  忠正里   雲林縣土庫鎮
# 7033400  1.500928  120.47167  23.642970       cm    雲林縣  斗南鎮  林子里   雲林縣斗南鎮
# 7033401  1.516509  120.47167  23.642970       cm    雲林縣  斗南鎮  林子里   雲林縣斗南鎮
#
#                                                   geometry
# 0        POLYGON ((120.70056 23.887, 120.70054 23.88697...
# 1        POLYGON ((120.70056 23.887, 120.70054 23.88697...
# 2        POLYGON ((120.70056 23.887, 120.70054 23.88697...
# 3        POLYGON ((120.70056 23.887, 120.70054 23.88697...
# 4        POLYGON ((120.70056 23.887, 120.70054 23.88697...
# ...                                                    ...
# 7033397  POLYGON ((120.33599 23.60124, 120.33606 23.601...
# 7033398  POLYGON ((120.33599 23.60124, 120.33606 23.601...
# 7033399  POLYGON ((120.37931 23.65355, 120.37917 23.653...
# 7033400  POLYGON ((120.48263 23.63219, 120.48205 23.632...
# 7033401  POLYGON ((120.48263 23.63219, 120.48205 23.632...
#
# [7033402 rows x 11 columns]

# %%
# Merge district-level area data

area = pd.read_excel('./Data/area.xlsx')
df = df.merge(area, on='district', how='inner')

# %%
# Create scaling factor using the number of villages in each district

village_counts = counties.groupby(["COUNTYNAME", "TOWNNAME"], as_index=False)["VILLNAME"].nunique()
village_counts.rename(columns={"VILLNAME": "factor"}, inplace=True)
village_counts["district"] = village_counts["COUNTYNAME"] + village_counts["TOWNNAME"]

df = df.merge(village_counts[["district", "factor"]], on="district", how="left")

# %%
# Identify flood events

# Time gap threshold and depth threshold
TIME_GAP_THRESHOLD = pd.Timedelta(hours=24)
DEPTH_THRESHOLD = 50
DEPTH_OUTLIER = 300

# Convert to timestamp format
df['timestamp'] = df['timestamp'].str.split('.').str[0] 
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort data by location and timestamp
df = df.sort_values(by=['district', 'timestamp'])

# Identify Flood Incidents (Group by district and timestamp while considering station_id)
df['time_diff'] = df.groupby(['district'])['timestamp'].diff()
df['new_incident'] = (df['time_diff'] > TIME_GAP_THRESHOLD).fillna(False)

# Assign an incident group at the district level, ignoring different station IDs
df['incident_group'] = df.groupby(['district'])['new_incident'].cumsum()

# Assign a unique ID based on district and start time of the incident
incident_keys = df.groupby(['district', 'incident_group'])['timestamp'].transform('min').astype(str) + '_' + df['district']
df['incident_id'] = pd.factorize(incident_keys)[0] + 1  # Assign unique numeric ID

# Aggregate incidents, merging across stations in the same district
flood_incidents = df.groupby(['district', 'incident_id']).agg(
    start_time=('timestamp', 'min'),
    end_time=('timestamp', 'max'),
    min_flood_depth=('value', 'min'),
    max_flood_depth=('value', 'max'),
    avg_flood_depth=('value', 'mean'),
    area=('area', 'first'),
    county=('county', 'first'),
    town=('town', 'first'),
    vil=('vil', 'first'),
    geometry=('geometry', 'first'),
    factor=('factor', 'first')
).reset_index()

# Filter incidents with outlier flood depth and exceeding the threshold
flood_incidents = flood_incidents[
    (flood_incidents['max_flood_depth'] < DEPTH_OUTLIER) &
    (flood_incidents['avg_flood_depth'] > DEPTH_THRESHOLD)
]

# %%
# Drop NAs
print("Number of missing values per column before dropping:")
print(flood_incidents.isna().sum())  # Counts NaN values for each column

flood_incidents = flood_incidents.dropna()
# Out:
# Number of missing values per column before dropping:
# district           0
# incident_id        0
# start_time         0
# end_time           0
# min_flood_depth    0
# max_flood_depth    0
# avg_flood_depth    0
# area               1
# county             1
# town               1
# vil                1
# geometry           1
# factor             1
# dtype: int64

# %%
flood_incidents.head()
# Out:
#     district  incident_id          start_time            end_time  \
# 274    嘉義市東區          275 2022-10-01 09:00:00 2022-10-01 10:27:48
# 468   嘉義縣六腳鄉          469 2020-03-21 20:09:29 2020-03-21 20:09:29
# 470   嘉義縣六腳鄉          471 2020-04-13 21:26:57 2020-04-13 21:26:57
# 473   嘉義縣六腳鄉          474 2020-05-06 22:38:20 2020-05-06 22:38:20
# 534   嘉義縣六腳鄉          535 2023-08-30 07:40:03 2023-08-30 12:01:43
#
#      min_flood_depth  max_flood_depth  avg_flood_depth        area county  \
# 274            294.2            295.1            294.9  30155600.0    嘉義市
# 468             77.3             77.3             77.3  62261900.0    嘉義縣
# 470             75.7             75.7             75.7  62261900.0    嘉義縣
# 473             78.0             78.0             78.0  62261900.0    嘉義縣
# 534              7.9            287.4            231.4  62261900.0    嘉義縣
#
#     town  vil                                           geometry  factor
# 274   東區  仁義里  POLYGON ((120.45899 23.4542, 120.45889 23.4541...    39.0
# 468  六腳鄉  古林村  POLYGON ((120.28176 23.49113, 120.28066 23.491...    25.0
# 470  六腳鄉  古林村  POLYGON ((120.28176 23.49113, 120.28066 23.491...    25.0
# 473  六腳鄉  古林村  POLYGON ((120.28176 23.49113, 120.28066 23.491...    25.0
# 534  六腳鄉  古林村  POLYGON ((120.28176 23.49113, 120.28066 23.491...    25.0

# %%
# Export as csv
flood_incidents.to_csv("flood_incidents.csv", index=False)
